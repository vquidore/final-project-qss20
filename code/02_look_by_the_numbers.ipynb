# %%
import pandas as pd

# %% [markdown]
# ## Read in CSVs and Excel files

# %%
FEIS_df = pd.read_excel(r"../files/START_FEIS_Data.xlsx")
male_white_df = pd.read_csv("../output/male_white")
male_white_df.head()
# Out:
#    Local ID                                        Region  \
# 0   6580618             California : CA START San Andreas
# 1   476148W                      North Carolina : Central
# 2  11157543  New Hampshire : Region 4 - Community Bridges
# 3    453394                           New York : Region 1
# 4    408407                           New York : Region 1
#
#   Date Enrolled in START Gender   Race        Date of birth  \
# 0    2020-12-23 00:00:00   Male  White  2004-12-21 00:00:00
# 1    2020-12-17 00:00:00   Male  White  2008-07-17 00:00:00
# 2    2020-12-15 00:00:00   Male  White  1991-11-27 00:00:00
# 3    2020-12-07 00:00:00   Male  White  2010-08-31 00:00:00
# 4    2020-12-07 00:00:00   Male  White  2003-04-18 00:00:00
#
#                 Ethnicity Level of Intellectual Disability  \
# 0  Not of Hispanic origin                         Moderate
# 1  Not of Hispanic origin                             Mild
# 2  Not of Hispanic origin                             Mild
# 3  Not of Hispanic origin                             Mild
# 4  Unknown, not collected                       None noted
#
#                                Psychiatric diagnoses Medical diagnoses  ...  \
# 0                                                NaN               NaN  ...
# 1  Attention-Deficit/Hyperactivity Disorder, Auti...               NaN  ...
# 2  Attention-Deficit/Hyperactivity Disorder (2001...               NaN  ...
# 3  Attention-Deficit/Hyperactivity Disorder, Auti...               NaN  ...
# 4  Attention-Deficit/Hyperactivity Disorder, Auti...        Neurologic  ...
#
#   In\nthe past year, did your family member use in-patient psychiatric services?  \
# 0                                                 No
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                 No
#
#   If\nyes, were the inpatient services that your family member received helpful to\nhim/her in your opinion?  ?  \
# 0                                                NaN
# 1                                        None at all
# 2                                Did not know/answer
# 3                                        Very little
# 4         Some, but not as much as was needed/wanted
#
#   How\nmuch help was available to you at night or on weekends if your family member\nhad a crisis?  \
# 0                                        Very little
# 1                                        None at all
# 2                                        Very little
# 3                                        Very little
# 4                                        Very little
#
#   Are\nthere options outside of the hospital for individuals experiencing a crisis to\ngo for help (i.e. crisis/hospital diversion beds)?  \
# 0                                        None at all
# 1                         All that was wanted/needed
# 2                                        None at all
# 3                                        None at all
# 4                                        Very little
#
#   Who\nwas the primary source of information about your family memberâ€™s mental health\nservices?  \
# 0                                              Other
# 1                        His/her service facilitator
# 2                                             No one
# 3                                              Other
# 4                     Your family member him/herself
#
#      If other, please describe..2  \
# 0  school based service providers
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#   During the past year, how much involvement\ndid you want to have in your family memberâ€™s treatment plan?  \
# 0                                              A lot
# 1                                              A lot
# 2                                               Some
# 3                                              A lot
# 4                                               Some
#
#   Was there any particular service that your\nfamily member needed that was not available?  \
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
#                 If yes, please describe the service.  \
# 0  "After Trevorâ€™s psychiatrist left the office...
# 1                                                NaN
# 2                                                NaN
# 3  Any services, he has not gotten any in two yea...
# 4                               Behavioral Coaching
#
#   What\nadvice would you give to service planners regarding the mental health service\nneeds of persons with IDD and their families?
# 0                  Declined to answer/did not know.
# 1  Ensure that individuals are getting the adequa...
# 2                                                NaN
# 3  really putting themselves in parents shoes and...
# 4                                                NaN
#
# [5 rows x 69 columns]
