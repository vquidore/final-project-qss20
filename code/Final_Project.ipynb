# %%
import pandas as pd

# %%
demographics = pd.read_excel(r"C:\Users\kaizh\qss20_w22_sipdata_disability\Dartmouth_Data_Set.xlsx")
FEIS_df = pd.read_excel(r"C:\Users\kaizh\qss20_w22_sipdata_disability\START_FEIS_Data.xlsx")

# %%
demographics.loc[demographics['Gender']=='Male']
males[['Gender']]
# FEIS_df.loc[]
# Out:
#       Local ID                                             Region  \
# 0      8085297                     California : CA START East Bay
# 1       440987                                New York : Region 3
# 2      8008815                     California : CA START East Bay
# 3       220396                                New York : Region 3
# 5      847532E                              North Carolina : East
# ...        ...                                                ...
# 4972  11130872  New Hampshire : Region 8 - One Sky Community S...
# 4975  11135821       New Hampshire : Region 4 - Community Bridges
# 4978  11139308  New Hampshire : Region 6 - Gateways Community ...
# 4981  11128837   New Hampshire : Region 7 - Moore Center Services
# 4982  11128335   New Hampshire : Region 7 - Moore Center Services
#
#             County    Start Coordinator Date Enrolled in START  \
# 0     Contra Costa        Mary Akhuetie             2020-12-30
# ...
